# %% [markdown]
# # Eksamensoppgaver
#
# ## 2P-Y
#
# I alle eksamener i 2P-Y så langt, har programmeringsoppgaver handler om å **forklare** programkode. Det er ingen oppgaver der du må skrive din egen kode.
#
# ```{figure} https://i.imgur.com/5XSDfr9.png
# ---
# height: 500px
# name: 2pyh24
# ---
# 2P-Y høst 2024
# ```
#
# ```{admonition} Løsningsforslag
# :class: warning, dropdown
# a)
# Uttrykket `200 * 0.975 ** x` er hvordan man skriver $200 * 0.975^x$ i Python. $200$ er hvor mye bedriften slipper ut i 2025. $0.975$ er vekstfaktoren for $2.5\%$ reduksjon. I sin helhet regner uttrykket ut hvor mye utslipp bedriften har i år $x$.
# b)
# While-løkka i programmet kjører for de 4 første årene (`x`). Variabelen `s` økes med årets utslipp hvert av de årene, så til slutt inneholder den mengden utslipp totalt de 4 første årene.
# ```
#
# ```{figure} https://i.imgur.com/XLM31m2.png
# ---
# height: 500px
# name: 2pyv24
# ---
# 2P-Y vår 2024
# ```
#
# ```{figure} https://i.imgur.com/FDgniM0.png
# ---
# height: 500px
# name: 2pyh23
# ---
# 2P-Y høst 2023. Bare b) er en programmeringsoppgave
# ```
#
# ```{figure} https://i.imgur.com/1GlDVi0.png
# ---
# height: 500px
# name: 2pyv23
# ---
# 2P-Y vår 2023. Bare c) er en programmeringsoppgave
# ```
#
# ```{figure} https://i.imgur.com/Y5GGg5o.png
# ---
# height: 500px
# name: 2pyeks
# ---
# 2P-Y eksempeleksamen.
# ```
